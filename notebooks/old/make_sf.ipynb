# %%
from sf import out

# %%
p1 = [[37.710307, -122.511978],
 [37.710307, -122.366753],
 [37.806529, -122.366753],
 [37.806529, -122.511978],
 [37.710307, -122.511978]]

p2 = [[37.750222, -122.451897],
 [37.750222, -122.348213],
 [37.813717, -122.348213],
 [37.813717, -122.451897],
 [37.750222, -122.451897]]

p3 = [[37.696997, -122.523136],
 [37.696997, -122.463398],
 [37.75728, -122.463398],
 [37.75728, -122.523136],
 [37.696997, -122.523136]]

# %%
import h3

# %%
s1 = h3.polyfill_polygon(p1, 9)
s2 = h3.polyfill_polygon(p2, 9)
s3 = h3.polyfill_polygon(p3, 9)

s1 = (s1 - s2) - s3

# %%
import util as u

# %%
#u.plot_hexset(s3).to_html()

# %%
out = [s1, s2, s3]

# %%
with open('sf.py', 'w') as f:
    f.write(str(out))

# %%
out
# Out:
# [{'89283082007ffff',
#   '8928308200fffff',
#   '89283082017ffff',
#   '89283082023ffff',
#   '89283082027ffff',
#   '8928308202bffff',
#   '8928308202fffff',
#   '89283082033ffff',
#   '89283082037ffff',
#   '8928308203bffff',
#   '89283082067ffff',
#   '89283082077ffff',
#   '89283082083ffff',
#   '89283082087ffff',
#   '8928308208fffff',
#   '89283082093ffff',
#   '89283082097ffff',
#   '892830820a3ffff',
#   '892830820a7ffff',
#   '892830820abffff',
#   '892830820afffff',
#   '892830820b3ffff',
#   '892830820b7ffff',
#   '892830820bbffff',
#   '89283082103ffff',
#   '89283082107ffff',
#   '8928308210bffff',
#   '8928308210fffff',
#   '89283082113ffff',
#   '89283082117ffff',
#   '8928308211bffff',
#   '89283082123ffff',
#   '89283082127ffff',
#   '8928308212bffff',
#   '89283082133ffff',
#   '89283082137ffff',
#   '8928308213bffff',
#   '89283082143ffff',
#   '89283082147ffff',
#   '8928308214bffff',
#   '8928308214fffff',
#   '89283082153ffff',
#   '89283082157ffff',
# ...
